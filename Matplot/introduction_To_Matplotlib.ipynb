# %% [markdown]
# # Made by:
# [Matplotlib Tutorial](https://www.youtube.com/watch?v=q7Bo_J8x_dw&list=PLQVvvaa0QuDfefDfXb9Yf0la1fPDKluPF)
#
# [Sentdex](https://www.youtube.com/channel/UCfzlCWGWYyIQ0aLC5w48gBQ)
#
# ---

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introduction

# %%
plt.plot([1,2,3],[5,7,4])
plt.show()
